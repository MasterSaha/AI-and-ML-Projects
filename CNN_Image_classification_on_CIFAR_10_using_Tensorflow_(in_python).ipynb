# %% [markdown]
# <a href="https://colab.research.google.com/github/MasterSaha/AI-and-ML-Projects/blob/main/CNN_Image_classification_on_CIFAR_10_using_Tensorflow_(in_python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np

# %%
(X_train, y_train), (X_test, y_test) = datasets.cifar10.load_data()
NUM_CLASSES = 10
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

y_train = to_categorical(y_train, NUM_CLASSES)
y_test = to_categorical(y_test, NUM_CLASSES)

# %%
class_names = [
    'airplane', 'automobile', 'bird', 'cat', 'deer',
    'dog', 'frog', 'horse', 'ship', 'truck'
]

plt.figure(figsize=(10,10))
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i])
    plt.xlabel(class_names[np.argmax(y_train[i])])
plt.show()

# %%
model = models.Sequential([
    layers.Input(shape=(32, 32, 3)),

    layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),

    layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.3),

    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

# %%
# Best Hyperparameters manually selected for this task
LEARNING_RATE = 0.001
WEIGHT_DECAY = 1e-4

optimizer = tf.keras.optimizers.AdamW(
    learning_rate=LEARNING_RATE,
    weight_decay=WEIGHT_DECAY
)

model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,171,178 (8.28 MB)
#  Trainable params: 2,169,770 (8.28 MB)
#  Non-trainable params: 1,408 (5.50 KB)

# %%
# Adding a learning rate scheduler to adjust LR during training
lr_callback = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)

history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    callbacks=[lr_callback]
)
# Out:
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 295s 917ms/step - accuracy: 0.4637 - loss: 1.6562 - val_accuracy: 0.1633 - val_loss: 3.1677 - learning_rate: 0.0010
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 290s 927ms/step - accuracy: 0.6295 - loss: 1.0654 - val_accuracy: 0.6163 - val_loss: 1.0952 - learning_rate: 0.0010
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 290s 928ms/step - accuracy: 0.6856 - loss: 0.8895 - val_accuracy: 0.6980 - val_loss: 0.8803 - learning_rate: 0.0010
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 316s 910ms/step - accuracy: 0.7216 - loss: 0.7883 - val_accuracy: 0.7033 - val_loss: 0.8468 - learning_rate: 0.0010
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 325s 920ms/step - accuracy: 0.7481 - loss: 0.7165 - val_accuracy: 0.7323 - val_loss: 0.7598 - learning_rate: 0.0010
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 291s 929ms/step - accuracy: 0.7703 - loss: 0.6606 - val_accuracy: 0.7412 - val_loss: 0.7667 - learning_rate: 0.0010
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 322s 928ms/step - accuracy: 0.7861 - loss: 0.6072 - val_accuracy: 0.7123 - val_loss: 0.8391 - learning_rate: 0.0010
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 317s 914ms/step - accuracy: 0.8004 - loss: 0.5610 - val_accuracy: 0.7487 - val_loss: 0.7595 - learning_rate: 0.0010
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 327s 931ms/step - accuracy: 0.8189 - loss: 0.5120 - val_accuracy: 0.7844 - val_loss: 0.6253 - learning_rate: 0.0010
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 284s 907ms/step - accuracy: 0.8274 - loss: 0.4814 - val_accuracy: 0.7897 - val_loss: 0.6259 - learning_rate: 0.0010
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 285s 910ms/step - accuracy: 0.8435 - loss: 0.4383 - val_accuracy: 0.7953 - val_loss: 0.6254 - learning_rate: 0.0010
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 291s 930ms/step - accuracy: 0.8543 - loss: 0.4054 - val_accuracy: 0.7982 - val_loss: 0.6179 - learning_rate: 0.0010
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 322s 928ms/step - accuracy: 0.8625 - loss: 0.3838 - val_accuracy: 0.7589 - val_loss: 0.7599 - learning_rate: 0.0010
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 284s 905ms/step - accuracy: 0.8747 - loss: 0.3542 - val_accuracy: 0.7730 - val_loss: 0.7168 - learning_rate: 0.0010
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 283s 905ms/step - accuracy: 0.8841 - loss: 0.3260 - val_accuracy: 0.7778 - val_loss: 0.7370 - learning_rate: 0.0010
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 290s 928ms/step - accuracy: 0.8901 - loss: 0.3088 - val_accuracy: 0.8026 - val_loss: 0.6208 - learning_rate: 0.0010
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 289s 925ms/step - accuracy: 0.8947 - loss: 0.2988 - val_accuracy: 0.8100 - val_loss: 0.6080 - learning_rate: 0.0010
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 289s 923ms/step - accuracy: 0.9027 - loss: 0.2712 - val_accuracy: 0.8090 - val_loss: 0.6191 - learning_rate: 0.0010
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 323s 928ms/step - accuracy: 0.9060 - loss: 0.2617 - val_accuracy: 0.7887 - val_loss: 0.7083 - learning_rate: 0.0010
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 290s 926ms/step - accuracy: 0.9098 - loss: 0.2538 - val_accuracy: 0.8114 - val_loss: 0.6225 - learning_rate: 0.0010
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 317s 910ms/step - accuracy: 0.9152 - loss: 0.2354 - val_accuracy: 0.8013 - val_loss: 0.6750 - learning_rate: 0.0010
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.9217 - loss: 0.2178
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 290s 927ms/step - accuracy: 0.9184 - loss: 0.2275 - val_accuracy: 0.7978 - val_loss: 0.7229 - learning_rate: 0.0010
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 290s 927ms/step - accuracy: 0.9385 - loss: 0.1756 - val_accuracy: 0.8279 - val_loss: 0.5829 - learning_rate: 5.0000e-04
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 289s 924ms/step - accuracy: 0.9460 - loss: 0.1564 - val_accuracy: 0.8187 - val_loss: 0.6189 - learning_rate: 5.0000e-04
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 291s 927ms/step - accuracy: 0.9496 - loss: 0.1444 - val_accuracy: 0.8223 - val_loss: 0.6275 - learning_rate: 5.0000e-04
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 286s 913ms/step - accuracy: 0.9512 - loss: 0.1395 - val_accuracy: 0.8270 - val_loss: 0.5984 - learning_rate: 5.0000e-04
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 326s 928ms/step - accuracy: 0.9540 - loss: 0.1313 - val_accuracy: 0.8254 - val_loss: 0.6079 - learning_rate: 5.0000e-04
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 860ms/step - accuracy: 0.9536 - loss: 0.1298
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 290s 926ms/step - accuracy: 0.9532 - loss: 0.1319 - val_accuracy: 0.8225 - val_loss: 0.6303 - learning_rate: 5.0000e-04
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 289s 925ms/step - accuracy: 0.9617 - loss: 0.1105 - val_accuracy: 0.8323 - val_loss: 0.6009 - learning_rate: 2.5000e-04
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 315s 904ms/step - accuracy: 0.9646 - loss: 0.1024 - val_accuracy: 0.8328 - val_loss: 0.6208 - learning_rate: 2.5000e-04
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 328s 923ms/step - accuracy: 0.9656 - loss: 0.0986 - val_accuracy: 0.8311 - val_loss: 0.6161 - learning_rate: 2.5000e-04
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 322s 924ms/step - accuracy: 0.9658 - loss: 0.0988 - val_accuracy: 0.8311 - val_loss: 0.6232 - learning_rate: 2.5000e-04
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 858ms/step - accuracy: 0.9684 - loss: 0.0891
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 289s 924ms/step - accuracy: 0.9691 - loss: 0.0891 - val_accuracy: 0.8357 - val_loss: 0.6106 - learning_rate: 2.5000e-04
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 323s 927ms/step - accuracy: 0.9714 - loss: 0.0847 - val_accuracy: 0.8333 - val_loss: 0.6181 - learning_rate: 1.2500e-04
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 322s 929ms/step - accuracy: 0.9701 - loss: 0.0841 - val_accuracy: 0.8363 - val_loss: 0.6031 - learning_rate: 1.2500e-04
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 316s 908ms/step - accuracy: 0.9718 - loss: 0.0810 - val_accuracy: 0.8321 - val_loss: 0.6406 - learning_rate: 1.2500e-04
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 327s 926ms/step - accuracy: 0.9735 - loss: 0.0780 - val_accuracy: 0.8365 - val_loss: 0.6097 - learning_rate: 1.2500e-04
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 865ms/step - accuracy: 0.9743 - loss: 0.0751
# Epoch 38: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 323s 930ms/step - accuracy: 0.9740 - loss: 0.0751 - val_accuracy: 0.8380 - val_loss: 0.6183 - learning_rate: 1.2500e-04
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 322s 932ms/step - accuracy: 0.9748 - loss: 0.0725 - val_accuracy: 0.8355 - val_loss: 0.6143 - learning_rate: 6.2500e-05
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 321s 927ms/step - accuracy: 0.9762 - loss: 0.0718 - val_accuracy: 0.8371 - val_loss: 0.6178 - learning_rate: 6.2500e-05
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 290s 928ms/step - accuracy: 0.9746 - loss: 0.0722 - val_accuracy: 0.8353 - val_loss: 0.6209 - learning_rate: 6.2500e-05
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 291s 931ms/step - accuracy: 0.9770 - loss: 0.0682 - val_accuracy: 0.8374 - val_loss: 0.6152 - learning_rate: 6.2500e-05
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 865ms/step - accuracy: 0.9775 - loss: 0.0690
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 322s 930ms/step - accuracy: 0.9777 - loss: 0.0675 - val_accuracy: 0.8386 - val_loss: 0.6144 - learning_rate: 6.2500e-05
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 292s 932ms/step - accuracy: 0.9773 - loss: 0.0672 - val_accuracy: 0.8367 - val_loss: 0.6162 - learning_rate: 3.1250e-05
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 321s 931ms/step - accuracy: 0.9782 - loss: 0.0655 - val_accuracy: 0.8369 - val_loss: 0.6209 - learning_rate: 3.1250e-05
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 291s 931ms/step - accuracy: 0.9794 - loss: 0.0640 - val_accuracy: 0.8366 - val_loss: 0.6215 - learning_rate: 3.1250e-05
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 291s 930ms/step - accuracy: 0.9777 - loss: 0.0663 - val_accuracy: 0.8372 - val_loss: 0.6183 - learning_rate: 3.1250e-05
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 868ms/step - accuracy: 0.9795 - loss: 0.0616
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 323s 934ms/step - accuracy: 0.9783 - loss: 0.0641 - val_accuracy: 0.8369 - val_loss: 0.6207 - learning_rate: 3.1250e-05
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 291s 930ms/step - accuracy: 0.9790 - loss: 0.0617 - val_accuracy: 0.8375 - val_loss: 0.6201 - learning_rate: 1.5625e-05
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 291s 929ms/step - accuracy: 0.9787 - loss: 0.0630 - val_accuracy: 0.8368 - val_loss: 0.6220 - learning_rate: 1.5625e-05

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10, 6))

# Plotting Learning Rate evolution
plt.plot(history.history['learning_rate'], label='Learning Rate', color='orange', marker='o')
plt.title('Learning Rate Schedule during Training')
plt.xlabel('Epoch')
plt.ylabel('Rate Value')
plt.yscale('log') # Log scale helps see small changes
plt.grid(True, which='both', linestyle='--', alpha=0.5)
plt.legend()

plt.show()

print(f"Final Best Hyperparameters Found:")
print(f"- Initial Learning Rate: {LEARNING_RATE}")
print(f"- Weight Decay (AdamW): {WEIGHT_DECAY}")
print(f"- Final Learning Rate: {history.history['learning_rate'][-1]}")
# Out:
# Final Best Hyperparameters Found:
# - Initial Learning Rate: 0.001
# - Weight Decay (AdamW): 0.0001
# - Final Learning Rate: 1.5625000742147677e-05

# %%
def plot_predictions(index):
    img = X_test[index]
    true_label = class_names[np.argmax(y_test[index])]
    pred_probs = model.predict(np.expand_dims(img, axis=0))
    pred_label = class_names[np.argmax(pred_probs)]

    plt.imshow(img)
    plt.title(f"True: {true_label} | Pred: {pred_label}")
    plt.axis('off')
    plt.show()

for i in range(5):
    plot_predictions(i)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
