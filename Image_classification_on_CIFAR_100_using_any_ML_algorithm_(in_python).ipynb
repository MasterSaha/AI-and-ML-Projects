# %% [markdown]
# <a href="https://colab.research.google.com/github/MasterSaha/AI-and-ML-Projects/blob/main/Image_classification_on_CIFAR_100_using_any_ML_algorithm_(in_python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np

# %%
(X_train, y_train), (X_test, y_test) = datasets.cifar100.load_data()

# %%
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

# %%
class_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle',
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel',
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock',
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster',
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose', 'sea',
    'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider',
    'squirrel', 'stock_car', 'sunflower', 'sweet_pepper', 'table', 'tank',
    'telephone', 'television', 'tiger', 'tractor', 'train', 'trout', 'tulip',
    'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm'
    ]

plt.figure(figsize=(10,10))
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i])
    plt.xlabel(class_names[np.argmax(y_train[i])])
plt.show()

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3)))
model.add(layers.Conv2D(32, (3,3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(layers.Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(layers.Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Dropout(0.25))

model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(100, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │        51,300 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,387,396 (5.29 MB)
#  Trainable params: 1,387,396 (5.29 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train,
                    epochs=100,
                    batch_size=64,
                    validation_split=0.2)
# Out:
# Epoch 1/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 375s 595ms/step - accuracy: 0.0138 - loss: 4.5471 - val_accuracy: 0.0241 - val_loss: 4.3965
# Epoch 2/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 375s 601ms/step - accuracy: 0.0550 - loss: 4.1386 - val_accuracy: 0.1104 - val_loss: 3.8879
# Epoch 3/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 354s 566ms/step - accuracy: 0.1091 - loss: 3.8000 - val_accuracy: 0.1391 - val_loss: 3.6969
# Epoch 4/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 352s 564ms/step - accuracy: 0.1475 - loss: 3.5893 - val_accuracy: 0.1925 - val_loss: 3.3888
# Epoch 5/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 350s 560ms/step - accuracy: 0.1768 - loss: 3.4240 - val_accuracy: 0.2137 - val_loss: 3.2661
# Epoch 6/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 383s 562ms/step - accuracy: 0.1976 - loss: 3.3080 - val_accuracy: 0.2286 - val_loss: 3.2362
# Epoch 7/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 374s 599ms/step - accuracy: 0.2175 - loss: 3.2063 - val_accuracy: 0.2490 - val_loss: 3.0885
# Epoch 8/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 361s 565ms/step - accuracy: 0.2370 - loss: 3.1109 - val_accuracy: 0.2674 - val_loss: 2.9832
# Epoch 9/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 400s 594ms/step - accuracy: 0.2517 - loss: 3.0340 - val_accuracy: 0.2827 - val_loss: 2.9368
# Epoch 10/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 381s 592ms/step - accuracy: 0.2638 - loss: 2.9770 - val_accuracy: 0.2861 - val_loss: 2.9008
# Epoch 11/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 383s 594ms/step - accuracy: 0.2722 - loss: 2.9082 - val_accuracy: 0.2954 - val_loss: 2.8374
# Epoch 12/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 352s 563ms/step - accuracy: 0.2849 - loss: 2.8438 - val_accuracy: 0.3121 - val_loss: 2.7795
# Epoch 13/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 386s 569ms/step - accuracy: 0.2941 - loss: 2.7945 - val_accuracy: 0.3162 - val_loss: 2.7762
# Epoch 14/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 379s 566ms/step - accuracy: 0.3020 - loss: 2.7539 - val_accuracy: 0.3316 - val_loss: 2.6627
# Epoch 15/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 369s 591ms/step - accuracy: 0.3117 - loss: 2.7128 - val_accuracy: 0.3262 - val_loss: 2.7107
# Epoch 16/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 387s 599ms/step - accuracy: 0.3174 - loss: 2.6840 - val_accuracy: 0.3358 - val_loss: 2.6724
# Epoch 17/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 357s 559ms/step - accuracy: 0.3276 - loss: 2.6378 - val_accuracy: 0.3471 - val_loss: 2.6133
# Epoch 18/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 350s 559ms/step - accuracy: 0.3343 - loss: 2.5986 - val_accuracy: 0.3505 - val_loss: 2.6023
# Epoch 19/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 372s 594ms/step - accuracy: 0.3395 - loss: 2.5614 - val_accuracy: 0.3480 - val_loss: 2.5985
# Epoch 20/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 375s 600ms/step - accuracy: 0.3474 - loss: 2.5372 - val_accuracy: 0.3531 - val_loss: 2.5747
# Epoch 21/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 356s 570ms/step - accuracy: 0.3505 - loss: 2.5098 - val_accuracy: 0.3449 - val_loss: 2.5929
# Epoch 22/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 356s 570ms/step - accuracy: 0.3560 - loss: 2.4683 - val_accuracy: 0.3651 - val_loss: 2.5213
# Epoch 23/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 380s 567ms/step - accuracy: 0.3605 - loss: 2.4524 - val_accuracy: 0.3622 - val_loss: 2.5501
# Epoch 24/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 377s 603ms/step - accuracy: 0.3674 - loss: 2.4316 - val_accuracy: 0.3717 - val_loss: 2.4831
# Epoch 25/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 376s 602ms/step - accuracy: 0.3733 - loss: 2.3965 - val_accuracy: 0.3688 - val_loss: 2.4857
# Epoch 26/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 354s 567ms/step - accuracy: 0.3789 - loss: 2.3724 - val_accuracy: 0.3841 - val_loss: 2.4515
# Epoch 27/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 375s 600ms/step - accuracy: 0.3817 - loss: 2.3617 - val_accuracy: 0.3771 - val_loss: 2.4567
# Epoch 28/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 364s 571ms/step - accuracy: 0.3862 - loss: 2.3302 - val_accuracy: 0.3852 - val_loss: 2.4461
# Epoch 29/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 356s 570ms/step - accuracy: 0.3897 - loss: 2.3159 - val_accuracy: 0.3874 - val_loss: 2.4310
# Epoch 30/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 384s 573ms/step - accuracy: 0.3962 - loss: 2.2945 - val_accuracy: 0.3811 - val_loss: 2.4511
# Epoch 31/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 359s 574ms/step - accuracy: 0.3993 - loss: 2.2764 - val_accuracy: 0.3919 - val_loss: 2.4165
# Epoch 32/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 380s 608ms/step - accuracy: 0.4032 - loss: 2.2438 - val_accuracy: 0.3933 - val_loss: 2.4164
# Epoch 33/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 366s 585ms/step - accuracy: 0.4079 - loss: 2.2424 - val_accuracy: 0.3847 - val_loss: 2.4626
# Epoch 34/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 383s 613ms/step - accuracy: 0.4085 - loss: 2.2198 - val_accuracy: 0.3868 - val_loss: 2.4260
# Epoch 35/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 375s 599ms/step - accuracy: 0.4154 - loss: 2.1938 - val_accuracy: 0.3808 - val_loss: 2.4588
# Epoch 36/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 375s 600ms/step - accuracy: 0.4160 - loss: 2.1842 - val_accuracy: 0.3883 - val_loss: 2.4250
# Epoch 37/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 366s 575ms/step - accuracy: 0.4210 - loss: 2.1597 - val_accuracy: 0.4030 - val_loss: 2.3614
# Epoch 38/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 382s 575ms/step - accuracy: 0.4246 - loss: 2.1467 - val_accuracy: 0.3936 - val_loss: 2.4002
# Epoch 39/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 381s 574ms/step - accuracy: 0.4267 - loss: 2.1383 - val_accuracy: 0.3906 - val_loss: 2.3963
# Epoch 40/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 400s 603ms/step - accuracy: 0.4313 - loss: 2.1229 - val_accuracy: 0.4053 - val_loss: 2.3540
# Epoch 41/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 376s 593ms/step - accuracy: 0.4307 - loss: 2.1113 - val_accuracy: 0.3899 - val_loss: 2.4194
# Epoch 42/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 364s 563ms/step - accuracy: 0.4345 - loss: 2.1032 - val_accuracy: 0.3895 - val_loss: 2.4287
# Epoch 43/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 352s 564ms/step - accuracy: 0.4412 - loss: 2.0686 - val_accuracy: 0.3941 - val_loss: 2.3851
# Epoch 44/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 403s 598ms/step - accuracy: 0.4437 - loss: 2.0562 - val_accuracy: 0.3973 - val_loss: 2.4094
# Epoch 45/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 357s 571ms/step - accuracy: 0.4466 - loss: 2.0402 - val_accuracy: 0.4024 - val_loss: 2.3653
# Epoch 46/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 356s 569ms/step - accuracy: 0.4516 - loss: 2.0318 - val_accuracy: 0.4025 - val_loss: 2.4164
# Epoch 47/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 401s 600ms/step - accuracy: 0.4527 - loss: 2.0185 - val_accuracy: 0.4075 - val_loss: 2.3620
# Epoch 48/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 372s 595ms/step - accuracy: 0.4530 - loss: 2.0110 - val_accuracy: 0.4025 - val_loss: 2.3756
# Epoch 49/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 353s 565ms/step - accuracy: 0.4593 - loss: 1.9926 - val_accuracy: 0.4098 - val_loss: 2.3390
# Epoch 50/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 370s 592ms/step - accuracy: 0.4593 - loss: 1.9789 - val_accuracy: 0.4022 - val_loss: 2.3680
# Epoch 51/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 386s 598ms/step - accuracy: 0.4604 - loss: 1.9830 - val_accuracy: 0.4060 - val_loss: 2.3480
# Epoch 52/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 376s 601ms/step - accuracy: 0.4656 - loss: 1.9546 - val_accuracy: 0.4079 - val_loss: 2.3434
# Epoch 53/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 358s 563ms/step - accuracy: 0.4665 - loss: 1.9489 - val_accuracy: 0.4081 - val_loss: 2.3696
# Epoch 54/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 375s 601ms/step - accuracy: 0.4712 - loss: 1.9303 - val_accuracy: 0.4065 - val_loss: 2.3797
# Epoch 55/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 375s 599ms/step - accuracy: 0.4717 - loss: 1.9263 - val_accuracy: 0.4020 - val_loss: 2.3812
# Epoch 56/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 355s 568ms/step - accuracy: 0.4753 - loss: 1.9234 - val_accuracy: 0.4047 - val_loss: 2.3730
# Epoch 57/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 400s 596ms/step - accuracy: 0.4748 - loss: 1.9182 - val_accuracy: 0.4061 - val_loss: 2.3637
# Epoch 58/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 376s 602ms/step - accuracy: 0.4797 - loss: 1.8879 - val_accuracy: 0.4113 - val_loss: 2.3542
# Epoch 59/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 357s 562ms/step - accuracy: 0.4812 - loss: 1.8886 - val_accuracy: 0.4128 - val_loss: 2.3525
# Epoch 60/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 377s 603ms/step - accuracy: 0.4831 - loss: 1.8787 - val_accuracy: 0.4160 - val_loss: 2.3251
# Epoch 61/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 357s 564ms/step - accuracy: 0.4838 - loss: 1.8784 - val_accuracy: 0.4057 - val_loss: 2.3951
# Epoch 62/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 352s 564ms/step - accuracy: 0.4881 - loss: 1.8641 - val_accuracy: 0.4080 - val_loss: 2.3637
# Epoch 63/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 372s 594ms/step - accuracy: 0.4900 - loss: 1.8476 - val_accuracy: 0.4130 - val_loss: 2.3363
# Epoch 64/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 373s 596ms/step - accuracy: 0.4926 - loss: 1.8434 - val_accuracy: 0.4147 - val_loss: 2.3536
# Epoch 65/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 372s 594ms/step - accuracy: 0.4929 - loss: 1.8478 - val_accuracy: 0.4140 - val_loss: 2.3639
# Epoch 66/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 369s 574ms/step - accuracy: 0.4931 - loss: 1.8316 - val_accuracy: 0.4165 - val_loss: 2.3144
# Epoch 67/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 354s 567ms/step - accuracy: 0.4948 - loss: 1.8229 - val_accuracy: 0.4104 - val_loss: 2.3732
# Epoch 68/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 382s 567ms/step - accuracy: 0.4963 - loss: 1.8018 - val_accuracy: 0.4136 - val_loss: 2.3779
# Epoch 69/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 354s 567ms/step - accuracy: 0.4976 - loss: 1.8002 - val_accuracy: 0.4085 - val_loss: 2.3938
# Epoch 70/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 373s 596ms/step - accuracy: 0.5019 - loss: 1.7925 - val_accuracy: 0.4137 - val_loss: 2.3724
# Epoch 71/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 374s 598ms/step - accuracy: 0.5054 - loss: 1.7872 - val_accuracy: 0.4151 - val_loss: 2.3678
# Epoch 72/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 376s 601ms/step - accuracy: 0.5046 - loss: 1.7865 - val_accuracy: 0.4242 - val_loss: 2.3211
# Epoch 73/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 364s 572ms/step - accuracy: 0.5108 - loss: 1.7577 - val_accuracy: 0.4116 - val_loss: 2.3733
# Epoch 74/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 355s 568ms/step - accuracy: 0.5093 - loss: 1.7587 - val_accuracy: 0.4228 - val_loss: 2.3371
# Epoch 75/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 383s 569ms/step - accuracy: 0.5128 - loss: 1.7453 - val_accuracy: 0.4123 - val_loss: 2.3827
# Epoch 76/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 379s 564ms/step - accuracy: 0.5096 - loss: 1.7549 - val_accuracy: 0.4110 - val_loss: 2.3677
# Epoch 77/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 413s 613ms/step - accuracy: 0.5120 - loss: 1.7497 - val_accuracy: 0.4102 - val_loss: 2.3868
# Epoch 78/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 390s 624ms/step - accuracy: 0.5160 - loss: 1.7338 - val_accuracy: 0.4208 - val_loss: 2.3478
# Epoch 79/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 371s 593ms/step - accuracy: 0.5203 - loss: 1.7196 - val_accuracy: 0.4159 - val_loss: 2.3660
# Epoch 80/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 384s 615ms/step - accuracy: 0.5205 - loss: 1.7223 - val_accuracy: 0.4181 - val_loss: 2.3624
# Epoch 81/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 363s 581ms/step - accuracy: 0.5221 - loss: 1.7052 - val_accuracy: 0.4196 - val_loss: 2.3708
# Epoch 82/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 353s 565ms/step - accuracy: 0.5210 - loss: 1.7123 - val_accuracy: 0.4148 - val_loss: 2.4000
# Epoch 83/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 358s 572ms/step - accuracy: 0.5225 - loss: 1.7083 - val_accuracy: 0.4184 - val_loss: 2.3592
# Epoch 84/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 357s 571ms/step - accuracy: 0.5272 - loss: 1.6946 - val_accuracy: 0.4188 - val_loss: 2.3615
# Epoch 85/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 357s 571ms/step - accuracy: 0.5296 - loss: 1.6761 - val_accuracy: 0.4180 - val_loss: 2.3475
# Epoch 86/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 378s 604ms/step - accuracy: 0.5314 - loss: 1.6710 - val_accuracy: 0.4162 - val_loss: 2.3758
# Epoch 87/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 359s 568ms/step - accuracy: 0.5286 - loss: 1.6773 - val_accuracy: 0.4277 - val_loss: 2.3579
# Epoch 88/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 382s 569ms/step - accuracy: 0.5319 - loss: 1.6662 - val_accuracy: 0.4152 - val_loss: 2.3807
# Epoch 89/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 357s 571ms/step - accuracy: 0.5325 - loss: 1.6685 - val_accuracy: 0.4147 - val_loss: 2.4041
# Epoch 90/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 356s 569ms/step - accuracy: 0.5332 - loss: 1.6613 - val_accuracy: 0.4170 - val_loss: 2.3863
# Epoch 91/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 403s 603ms/step - accuracy: 0.5341 - loss: 1.6484 - val_accuracy: 0.4196 - val_loss: 2.3423
# Epoch 92/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 354s 566ms/step - accuracy: 0.5309 - loss: 1.6646 - val_accuracy: 0.4246 - val_loss: 2.3424
# Epoch 93/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 381s 564ms/step - accuracy: 0.5365 - loss: 1.6456 - val_accuracy: 0.4190 - val_loss: 2.4106
# Epoch 94/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 353s 565ms/step - accuracy: 0.5412 - loss: 1.6319 - val_accuracy: 0.4195 - val_loss: 2.3621
# Epoch 95/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 354s 567ms/step - accuracy: 0.5372 - loss: 1.6447 - val_accuracy: 0.4253 - val_loss: 2.3417
# Epoch 96/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 356s 569ms/step - accuracy: 0.5405 - loss: 1.6305 - val_accuracy: 0.4229 - val_loss: 2.3835
# Epoch 97/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 375s 601ms/step - accuracy: 0.5401 - loss: 1.6369 - val_accuracy: 0.4215 - val_loss: 2.3902
# Epoch 98/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 354s 567ms/step - accuracy: 0.5488 - loss: 1.6026 - val_accuracy: 0.4217 - val_loss: 2.3949
# Epoch 99/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 353s 565ms/step - accuracy: 0.5414 - loss: 1.6181 - val_accuracy: 0.4188 - val_loss: 2.4148
# Epoch 100/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 357s 572ms/step - accuracy: 0.5452 - loss: 1.6106 - val_accuracy: 0.4208 - val_loss: 2.3817

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
def plot_predictions(index):
    img = X_test[index]
    true_label = class_names[np.argmax(y_test[index])]
    pred_probs = model.predict(np.expand_dims(img, axis=0))
    pred_label = class_names[np.argmax(pred_probs)]

    plt.imshow(img)
    plt.title(f"True: {true_label} | Pred: {pred_label}")
    plt.axis('off')
    plt.show()

for i in range(5):
    plot_predictions(i)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
